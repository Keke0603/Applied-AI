# %% [markdown]
# <a href="https://colab.research.google.com/github/Keke0603/Applied-AI/blob/main/trans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required library
# !pip install sacrebleu

import torch
import random
import sacrebleu

from transformers import MarianMTModel, MarianTokenizer, logging
from datasets import load_dataset

# Suppress warnings
logging.set_verbosity_error()

# Load dataset
dataset = load_dataset("opus100", "en-fr", split="test")

# Select random samples
sample_indices = random.sample(range(len(dataset)), 15)
sampled_data = [dataset[i] for i in sample_indices]

# Extract English and French sentences
english_sentences = [ex["translation"]["en"] for ex in sampled_data]
french_references = [[ex["translation"]["fr"]] for ex in sampled_data]

# Load model and tokenizer
model_name = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Tokenize input
inputs = tokenizer(
    english_sentences,
    return_tensors="pt",
    padding=True,
    truncation=True,
    max_length=128
)

# Generate translations
with torch.no_grad():
    generated_tokens = model.generate(**inputs)

# Decode outputs
translated_sentences = tokenizer.batch_decode(
    generated_tokens,
    skip_special_tokens=True
)

# Print results
print("\n--- Translations ---\n")
for idx, (src, pred, ref) in enumerate(
        zip(english_sentences, translated_sentences, french_references), 1):
    print(f"Example {idx}")
    print(f"Source    : {src}")
    print(f"Predicted : {pred}")
    print(f"Reference : {ref[0]}")
    print()

# Calculate BLEU score
bleu_score = sacrebleu.corpus_bleu(translated_sentences, french_references)

print("BLEU Score:", bleu_score.score)
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2.0.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (6.0.2)
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 4.5 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.2.0 sacrebleu-2.6.0
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# en-fr/test-00000-of-00001.parquet:   0%|          | 0.00/327k [00:00<?, ?B/s]
# en-fr/train-00000-of-00001.parquet:   0%|          | 0.00/142M [00:00<?, ?B/s]
# en-fr/validation-00000-of-00001.parquet:   0%|          | 0.00/334k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# --- Translations ---
#
# Example 1
# Source    : Separate mother and child until mother is appropriately treated and no longer infectious.
# Predicted : Séparer la mère et l'enfant jusqu'à ce que la mère soit correctement traitée et ne soit plus infectieuse.
# Reference : Il faut séparer la mère du nourrisson jusqu'à ce que la mère soit bien traitée et ne soit plus contagieuse.
#
# Example 2
# Source    : Restrictions on Use
# Predicted : Restrictions à l'utilisation
# Reference : Restrictions d’utilisation
#
# Example 3
# Source    : In no case shall there be restrictions on the right to information referred to in article 18 that could constitute conduct defined in article 2 or be in violation of article 17, paragraph 1.
# Predicted : En aucun cas le droit à l ' information visé à l ' article 18 ne peut faire l ' objet de restrictions qui pourraient constituer un comportement défini à l ' article 2 ou constituer une violation du paragraphe 1 de l ' article 17.
# Reference : En aucun cas ces restrictions au droit aux informations prévues à l'article 18 ne peuvent être admises si elles constituent un comportement défini à l'article 2 ou une violation du paragraphe 1 de l'article 17.
#
# Example 4
# Source    : I wanna know now.
# Predicted : Je veux savoir maintenant.
# Reference : Je veux savoir maintenant.
#
# Example 5
# Source    : 2008-07-24 -- 4 Wing 42 Radar Squadron a mobile unit The 4 Wing Cold Lake, Alta. unit known as 42 Radar Squadron (RS) has been in operation for over 40 years.
# Predicted : 2008-07-24 -- 4e Escadron de radars de la 4e Escadre Cold Lake (Alberta) Une unité mobile L'unité de la 4e Escadre Cold Lake (Alberta) connue sous le nom de 42e Escadron de radars (RS) est en service depuis plus de 40 ans.
# Reference : 2008-07-24 -- 4e Escadre Le 42e Escadron de radar, une unité mobile Le 42e Escadron de radar (ER) de la 4e Escadre Cold Lake (Alberta) existe depuis plus de 40 ans.
#
# Example 6
# Source    : Advancing Canadian Entrepreneurship (ACE) Inc., a national organization for entrepreneurship training and education, advances Canadian entrepreneurship by organizing and motivating teams of university and college students to practice and teach others the principles and values of entrepreneurship.
# Predicted : Promouvoir l'entrepreneuriat canadien (ACE) Inc., un organisme national de formation et d'éducation en entrepreneuriat, fait progresser l'entrepreneuriat canadien en organisant et en incitant des équipes d'étudiants universitaires et collégiaux à pratiquer et à enseigner aux autres les principes et les valeurs de l'entrepreneuriat.
# Reference : Advancing Canadian Entrepreneurship (ACE) Inc. est un organisme national de formation et d'éducation en entrepreneurship qui fait la promotion de l'entrepreneurship au Canada en organisant et en motivant des équipes d'étudiants des collèges et des universités qui mettent en pratique les principes et les valeurs de l'entrepreneurship et qui les enseignent aux autres.
#
# Example 7
# Source    : Mr President, I should like to congratulate Mr Pronk for the work he has done, following Mr Mather, who dealt with it at first reading.
# Predicted : Monsieur le Président, je voudrais féliciter M. Pronk pour le travail qu'il a accompli, à la suite de M. Mather, qui l'a traité en première lecture.
# Reference : Monsieur le Président, je voudrais remercier M. Pronk pour son travail, reprenant le flambeau à M. Mather qui s'était occupé de cette question en première lecture.
#
# Example 8
# Source    : I don't know.
# Predicted : Je ne sais pas.
# Reference : Je ne sais pas.
#
# Example 9
# Source    : Um, light-headed, tired, nauseous.
# Predicted : Euh, tête légère, fatiguée, nausée.
# Reference : Maux de tête, fatigué, nauséeux.
#
# Example 10
# Source    : President Stephen: I offer my congratulations to Mr. Miguel d'Escoto Brockmann on his election to the presidency of the General Assembly at its sixty-third session.
# Predicted : Le Président Stephen (parle en anglais) : Je félicite M. Miguel d'Escoto Brockmann de son élection à la présidence de la soixante-troisième session de l'Assemblée générale.
# Reference : Le Président Stephen (parle en anglais) : J'adresse mes félicitations à M. Miguel d'Escoto-Brockmann pour son élection à la présidence de l'Assemblée générale à sa soixante-troisième session.
#
# Example 11
# Source    : And just like any fluid, the atmosphere has a weight.
# Predicted : Et comme n'importe quel fluide, l'atmosphère a un poids.
# Reference : Et comme n'importe quel fluide, L'atmosphère a un poid.
#
# Example 12
# Source    : Certificates of Discontinuance (CCA - COOP) File Number Name of Corporation New Jurisdiction Date of Discontinuance 065006-4 XCAN GRAIN POOL LTD. became 408376-8 2002-06-11
# Predicted : Certificats d'abandon (CCA - COOP) Numéro de dossier Nom de la société Nouvelle juridiction Date d'abandon 065006-4 XCAN GRAIN POOL LTD. est devenu 408376-8 2002-06-11
# Reference : Certificats de changement de régime (LCC - COOP) No. dossier Dénomination de la société Nouvelle juridiction Date du changement de régime 065006-4 XCAN GRAIN POOL LTD. became 408376-8 2002-06-11
#
# Example 13
# Source    : "Today, Canada has gone from economic laggard to leader and we can look forward to the future with tremendous confidence."
# Predicted : « Aujourd'hui, le Canada est passé d'un pays à l'autre et nous pouvons espérer l'avenir avec une grande confiance. »
# Reference : « Le Canada est passé de la queue à la tête du peloton économique, et nous pouvons envisager l'avenir avec la plus grande confiance.
#
# Example 14
# Source    : Let's say I wanna join, right?
# Predicted : Disons que je veux me joindre, non ?
# Reference : Supposons que je veuille m'y joindre.
#
# Example 15
# Source    : ACCOUNTING STANDARDS
# Predicted : NORMES COMPTABLES
# Reference : NORMES COMPTABLES
#
# BLEU Score: 43.87083138701936
